# %% [markdown]
# # Gathering Data

# %%
#Import all packages needed
import pandas as pd
import numpy as np
import tweepy
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
import re
import json 
import os
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %%
#read csv file
twitter_arc = pd.read_csv('twitter-archive-enhanced-2.csv')

# %%
# read tsv file from url

url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
response = requests.get(url)
file_name=url.split('/')[-1]
if not os.path.isfile(file_name):
  with open(file_name, mode='wb') as f:
    f.write(response.content)

# %%
image_predictions = pd.read_csv('image-predictions.tsv', sep='\t')

# %%
#read tweet_json.txt file line by line into a pandas DataFrame
df = []

with open('tweet_json.txt', 'r') as file:
    for line in file:
        tweet = json.loads(line)
        tweet_id = tweet['id']
        retweet_count = tweet['retweet_count']
        fav_count = tweet['favorite_count']
        df.append({'tweet_id':tweet_id,
                       'retweet_count': retweet_count,
                       'favorite_count': fav_count})
        
tweet_json = pd.DataFrame(df)

# %% [markdown]
# ## Assessing data

# %% [markdown]
# ### Visual assessment

# %%
twitter_arc
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
image_predictions
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
tweet_json
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           8853           39467
# 1     892177421306343426           6514           33819
# 2     891815181378084864           4328           25461
# 3     891689557279858688           8964           42908
# 4     891327558926688256           9774           41048
# ...                  ...            ...             ...
# 2349  666049248165822465             41             111
# 2350  666044226329800704            147             311
# 2351  666033412701032449             47             128
# 2352  666029285002620928             48             132
# 2353  666020888022790149            532            2535
#
# [2354 rows x 3 columns]

# %% [markdown]
# ### Programmatic assessment

# %%
twitter_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
twitter_arc.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
twitter_arc.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 705   785639753186217984                    NaN                  NaN
# 1957  673583129559498752                    NaN                  NaN
# 21    887705289381826560                    NaN                  NaN
# 388   826598365270007810                    NaN                  NaN
# 1373  701981390485725185                    NaN                  NaN
#
#                       timestamp  \
# 705   2016-10-11 00:34:48 +0000
# 1957  2015-12-06 19:21:47 +0000
# 21    2017-07-19 16:06:48 +0000
# 388   2017-02-01 01:09:42 +0000
# 1373  2016-02-23 04:06:20 +0000
#
#                                                  source  \
# 705   <a href="http://twitter.com/download/iphone" r...
# 1957  <a href="http://twitter.com/download/iphone" r...
# 21    <a href="http://twitter.com/download/iphone" r...
# 388   <a href="http://twitter.com/download/iphone" r...
# 1373  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
twitter_arc['tweet_id'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2351    False
# 2352    False
# 2353    False
# 2354    False
# 2355    False
# Name: tweet_id, Length: 2356, dtype: bool

# %%
twitter_arc['name'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2351    False
# 2352    False
# 2353    False
# 2354    False
# 2355    False
# Name: name, Length: 2356, dtype: bool

# %%
twitter_arc.name.value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Lucy        11
# Cooper      11
#           ...
# Willy        1
# Jeb          1
# Toffee       1
# Pete         1
# Damon        1
# Name: name, Length: 957, dtype: int64

# %%
twitter_arc.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
twitter_arc[twitter_arc.rating_numerator <= 5].loc[0:, :]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 45    883482846933004288                    NaN                  NaN
# 315   835152434251116546                    NaN                  NaN
# 605   798576900688019456                    NaN                  NaN
# 730   781661882474196992                    NaN                  NaN
# 765   777885040357281792                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2334  666293911632134144                    NaN                  NaN
# 2335  666287406224695296                    NaN                  NaN
# 2338  666104133288665088                    NaN                  NaN
# 2349  666051853826850816                    NaN                  NaN
# 2351  666049248165822465                    NaN                  NaN
#
#                       timestamp  \
# 45    2017-07-08 00:28:19 +0000
# 315   2017-02-24 15:40:31 +0000
# 605   2016-11-15 17:22:24 +0000
# ...

# %%
twitter_arc[twitter_arc.rating_numerator > 20].loc[0:, :]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 290   838150277551247360           8.381455e+17         2.195506e+07
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 340   832215909146226688                    NaN                  NaN
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 695   786709082849828864                    NaN                  NaN
# 763   778027034220126208                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 979   749981277374128128                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# ...

# %%
twitter_arc.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
twitter_arc.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
twitter_arc[twitter_arc.name.str.islower()].head(5)
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 22   887517139158093824                    NaN                  NaN
# 56   881536004380872706                    NaN                  NaN
# 118  869988702071779329                    NaN                  NaN
# 169  859196978902773760                    NaN                  NaN
# 193  855459453768019968                    NaN                  NaN
#
#                      timestamp  \
# 22   2017-07-19 03:39:09 +0000
# 56   2017-07-02 15:32:16 +0000
# 118  2017-05-31 18:47:24 +0000
# 169  2017-05-02 00:04:57 +0000
# 193  2017-04-21 16:33:22 +0000
#
#                                                 source  \
# 22   <a href="http://twitter.com/download/iphone" r...
# 56   <a href="http://twitter.com/download/iphone" r...
# 118  <a href="http://twitter.com/download/iphone" r...
# 169  <a href="http://twitter.com/download/iphone" r...
# 193  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_predictions.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
tweet_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   int64
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %%
tweet_json.describe()
# Out:
#            tweet_id  retweet_count  favorite_count
# count  2.354000e+03    2354.000000     2354.000000
# mean   7.426978e+17    3164.797366     8080.968564
# std    6.852812e+16    5284.770364    11814.771334
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783975e+17     624.500000     1415.000000
# 50%    7.194596e+17    1473.500000     3603.500000
# 75%    7.993058e+17    3652.000000    10122.250000
# max    8.924206e+17   79515.000000   132810.000000

# %% [markdown]
# ### Quality :

# %% [markdown]
# #### 1.twitter_archive_enh contains retweets, not all are original tweets.

# %% [markdown]
# #### 2.twitter_archive_enh has unused columns, i.e. 'in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'

# %% [markdown]
# #### 3.timestamp column is str instead of datetime

# %% [markdown]
# #### 4.source formate

# %% [markdown]
# #### 5.'name' has values that are the string "None" instead of NaN

# %% [markdown]
# #### 6.'name' contains incorrect values like 'a', 'an', 'the', starting with non-capitalized letter in twitter_archive_enh

# %% [markdown]
# #### 7.rating_denominator column has values less than 10 and values more than 10

# %% [markdown]
# #### 8.incorrect rating_numerator

# %% [markdown]
# #### 9.'None' values in dog stage columns should be 'NaN' in twitter_archive_enh.

# %% [markdown]
# ### Tidiness

# %% [markdown]
# #### 1.Variable dog stage are in 4 columns instead of one in twitter_archive_enh.

# %% [markdown]
# #### 2.All datasets should be combined into 1 dataset only

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# #### 1.twitter_archive_enh contains retweets and reply not all are original tweets.

# %% [markdown]
# #### 2.twitter_archive_enh has unused columns, i.e. 'in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'.

# %% [markdown]
# ##### Define : keep original ratings (no retweets,no reply) that have images, Delete columns that won't be used for analysis

# %% [markdown]
# ##### code:

# %%
#copies from df 
twitter_arc_clean = twitter_arc.copy()
image_predictions_clean = image_predictions.copy()
tweet_json_clean = tweet_json.copy()

# %%
# creating a list of tweet_ids with images "tweets_with_image" and confirming its length
tweets_with_image = list(image_predictions_clean.tweet_id.unique())

# confirming that all the tweets with images exist in the archive dataset
len(tweets_with_image) == twitter_arc_clean.tweet_id.isin(tweets_with_image).sum()

# Cleaning in action ;)
twitter_arc_clean = twitter_arc_clean[twitter_arc_clean.tweet_id.isin(tweets_with_image)]

# %%
# Throwback to the archive dataset to extract the tweets that include data in the retweet_status_id.
retweet_entries = twitter_arc_clean.retweeted_status_id.notnull()
twitter_arc_clean[retweet_entries].shape[0]

# Dropping the retweets from the archive data set
twitter_arc_clean = twitter_arc_clean[~retweet_entries]

# Extracting replies entries with the same method as the retweets
replies_entries = twitter_arc_clean.in_reply_to_status_id.notnull()
twitter_arc_clean[replies_entries].shape[0]
twitter_arc_clean = twitter_arc_clean[~replies_entries]

# Now we check the image_prediction table for extra tweet ids not in the archive table
np.logical_not(image_predictions_clean.tweet_id.isin(list(twitter_arc_clean.tweet_id)))

# Dropping the retweets and replies ids from the image prediction dataframe
image_predictions_clean = image_predictions_clean[~np.logical_not(image_predictions_clean.tweet_id.isin(list(twitter_arc_clean.tweet_id)))]

# %%
# Remove 'retweeted_status_id', 'retweeted_status_user_id' , in_reply_to_user_id ,in_reply_to_status_id   and 
# 'retweeted_status_timestamp' columns
twitter_arc_clean = twitter_arc_clean.drop(['retweeted_status_id', 
                        'retweeted_status_user_id', 
                        'retweeted_status_timestamp',"in_reply_to_status_id",'in_reply_to_user_id'], 
                       axis=1)

# %% [markdown]
# ##### testing:

# %%
twitter_arc_clean.sample(3)
# Out:
#                 tweet_id                  timestamp  \
# 1858  675501075957489664  2015-12-12 02:23:01 +0000
# 646   793150605191548928  2016-10-31 18:00:14 +0000
# 906   758041019896193024  2016-07-26 20:47:17 +0000
#
#                                                  source  \
# 1858  <a href="http://twitter.com/download/iphone" r...
# 646   <a href="http://twitter.com/download/iphone" r...
# 906   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 1858  I shall call him squishy and he shall be mine,...
# 646   This is Nida. She's a free elf. Waited so long...
# 906   Teagan reads entire books in store so they're ...
#
#                                           expanded_urls  rating_numerator  \
# 1858  https://twitter.com/dog_rates/status/675501075...                13
# 646   https://twitter.com/dog_rates/status/793150605...                11
# ...

# %%
twitter_arc_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1971 non-null   int64
#  1   timestamp           1971 non-null   object
#  2   source              1971 non-null   object
#  3   text                1971 non-null   object
#  4   expanded_urls       1971 non-null   object
#  5   rating_numerator    1971 non-null   int64
#  6   rating_denominator  1971 non-null   int64
#  7   name                1971 non-null   object
#  8   doggo               1971 non-null   object
#  9   floofer             1971 non-null   object
#  10  pupper              1971 non-null   object
#  11  puppo               1971 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 200.2+ KB

# %%
image_predictions_clean.sample(3)
# Out:
#                 tweet_id                                          jpg_url  \
# 1657  810896069567610880  https://pbs.twimg.com/media/C0DhpcrUAAAnx88.jpg
# 468   675109292475830276  https://pbs.twimg.com/media/CV54UQTXAAAGf-j.jpg
# 1264  749064354620928000  https://pbs.twimg.com/media/CmU2DVWWgAArvp3.jpg
#
#       img_num                     p1   p1_conf  p1_dog                  p2  \
# 1657        1  flat-coated_retriever  0.820804    True  Labrador_retriever
# 468         1              dalmatian  0.989519    True      English_setter
# 1264        2                    pug  0.985222    True   Brabancon_griffon
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 1657  0.082318    True       curly-coated_retriever  0.067461    True
# 468   0.005258    True  German_short-haired_pointer  0.001443    True
# 1264  0.003314    True                     Pekinese  0.002989    True

# %%
image_predictions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  1971 non-null   int64
#  1   jpg_url   1971 non-null   object
#  2   img_num   1971 non-null   int64
#  3   p1        1971 non-null   object
#  4   p1_conf   1971 non-null   float64
#  5   p1_dog    1971 non-null   bool
#  6   p2        1971 non-null   object
#  7   p2_conf   1971 non-null   float64
#  8   p2_dog    1971 non-null   bool
#  9   p3        1971 non-null   object
#  10  p3_conf   1971 non-null   float64
#  11  p3_dog    1971 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 159.8+ KB

# %% [markdown]
# #### 3.timestamp column is str instead of datetime

# %% [markdown]
# ##### Define : timestamp column is str instead of datetime

# %% [markdown]
# ##### code :

# %%
twitter_arc_clean.timestamp = pd.to_datetime(twitter_arc_clean.timestamp)

# %% [markdown]
# ##### testing :

# %%
twitter_arc_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1971 non-null   int64
#  1   timestamp           1971 non-null   datetime64[ns, UTC]
#  2   source              1971 non-null   object
#  3   text                1971 non-null   object
#  4   expanded_urls       1971 non-null   object
#  5   rating_numerator    1971 non-null   int64
#  6   rating_denominator  1971 non-null   int64
#  7   name                1971 non-null   object
#  8   doggo               1971 non-null   object
#  9   floofer             1971 non-null   object
#  10  pupper              1971 non-null   object
#  11  puppo               1971 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(3), object(8)
# memory usage: 200.2+ KB

# %% [markdown]
# #### 4.source formate

# %% [markdown]
# ##### define : source column is html tag \<a> we can extract the source of the tweet

# %% [markdown]
# ##### code :

# %%
twitter_arc_clean.source
# Out:
# 0       <a href="http://twitter.com/download/iphone" r...
# 1       <a href="http://twitter.com/download/iphone" r...
# 2       <a href="http://twitter.com/download/iphone" r...
# 3       <a href="http://twitter.com/download/iphone" r...
# 4       <a href="http://twitter.com/download/iphone" r...
#                               ...
# 2351    <a href="http://twitter.com/download/iphone" r...
# 2352    <a href="http://twitter.com/download/iphone" r...
# 2353    <a href="http://twitter.com/download/iphone" r...
# 2354    <a href="http://twitter.com/download/iphone" r...
# 2355    <a href="http://twitter.com/download/iphone" r...
# Name: source, Length: 1971, dtype: object

# %%
twitter_arc_clean.source.unique()
# Out:
# array(['<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>'],
#       dtype=object)

# %%
#make a function fix_source which extract the strings between tags
def fix_source(x):
    'x is an html string from the source column in df_arch_cleaned dataset'
    #find the first closed  tag >
    i= x.find('>') + 1
    # find the first open tag after the previous <
    j =x[i:].find('<')
    # extract the text in between
    return x[i:][:j]

# %%
twitter_arc_clean.source = twitter_arc_clean.source.apply(lambda x: fix_source(x)).astype('category')

# %% [markdown]
# ##### testing :

# %%
twitter_arc_clean.source
# Out:
# 0       Twitter for iPhone
# 1       Twitter for iPhone
# 2       Twitter for iPhone
# 3       Twitter for iPhone
# 4       Twitter for iPhone
#                ...
# 2351    Twitter for iPhone
# 2352    Twitter for iPhone
# 2353    Twitter for iPhone
# 2354    Twitter for iPhone
# 2355    Twitter for iPhone
# Name: source, Length: 1971, dtype: category
# Categories (3, object): ['TweetDeck', 'Twitter Web Client', 'Twitter for iPhone']

# %%
twitter_arc_clean.source.unique()
# Out:
# array(['<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>'],
#       dtype=object)

# %% [markdown]
# #### 5.name has values that are the string "None" instead of NaN

# %% [markdown]
# #### 6.Looking programmatically, some names are inaccurate such as "a", "an", "the", "very", "by", etc

# %% [markdown]
# ##### define : filter out all non-capitalized names and assign to NaN, update "None" names to NaN as well

# %% [markdown]
# ##### code :

# %%
twitter_arc_clean.name.value_counts()
# Out:
# None          524
# a              55
# Charlie        11
# Oliver         10
# Cooper         10
#              ...
# Lacy            1
# Burt            1
# Christoper      1
# Maya            1
# Damon           1
# Name: name, Length: 935, dtype: int64

# %%
# Find all names that start with a lowercase letter
lowercase_names = []
for row in twitter_arc_clean['name']:
    if row[0].islower() and row not in lowercase_names:
        lowercase_names.append(row)
print(lowercase_names)
# Out:
# ['such', 'a', 'quite', 'one', 'incredibly', 'very', 'my', 'not', 'his', 'an', 'just', 'getting', 'this', 'unacceptable', 'all', 'infuriating', 'the', 'actually', 'by', 'officially', 'light', 'space']

# %%
# Replace all names that start with a lowercase letter with a NaN
twitter_arc_clean['name'].replace(lowercase_names, 
                        np.nan,
                       inplace = True)

# Replace all 'None's with a NaN
twitter_arc_clean['name'].replace('None', 
                        np.nan,
                       inplace = True)

# %% [markdown]
# ##### testing :

# %%
twitter_arc_clean.name.value_counts()
# Out:
# Charlie       11
# Cooper        10
# Oliver        10
# Lucy          10
# Tucker         9
#               ..
# Karl           1
# Lacy           1
# Burt           1
# Christoper     1
# Damon          1
# Name: name, Length: 912, dtype: int64

# %% [markdown]
# #### 7.The rating_numerator column should of type float and also it should be correctly extracted.

# %% [markdown]
# ##### Define : Extract rating scores correctly from tweet text and convert it to float

# %% [markdown]
# ##### code :

# %%
twitter_arc_clean[twitter_arc_clean.text.str.contains(r"(\d+\.\d*\/\d+)")][['text', 'rating_numerator']]
# Out:
#                                                    text  rating_numerator
# 45    This is Bella. She hopes her smile made you sm...                 5
# 695   This is Logan, the Chow who lived. He solemnly...                75
# 763   This is Sophie. She's a Jubilant Bush Pupper. ...                27
# 1712  Here we have uncovered an entire battalion of ...                26

# %%
new_ratings = twitter_arc_clean[twitter_arc_clean.text.str.contains(r"(\d+\.\d*\/\d+)")]['text'].str.extract(r"(\d+\.\d*(?=\/\d+))")
new_ratings
# Out:
#           0
# 45     13.5
# 695    9.75
# 763   11.27
# 1712  11.26

# %%
twitter_arc_clean.loc[new_ratings.index, 'rating_numerator'] = new_ratings.values

# %%
twitter_arc_clean.rating_numerator = twitter_arc_clean.rating_numerator.astype('float')

# %% [markdown]
# ##### testing :

# %%
twitter_arc_clean.sample(3)
# Out:
#                tweet_id                 timestamp  \
# 339  832273440279240704 2017-02-16 17:00:25+00:00
# 261  842846295480000512 2017-03-17 21:13:10+00:00
# 828  768970937022709760 2016-08-26 00:38:52+00:00
#
#                                                 source  \
# 339  <a href="http://twitter.com/download/iphone" r...
# 261  <a href="http://twitter.com/download/iphone" r...
# 828  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                   text  \
# 339  Say hello to Smiley. He's a blind therapy dogg...
# 261  This is Charlie. He's wishing you a very fun a...
# 828  This is Kirby. His bowl weighs more than him. ...
#
#                                          expanded_urls  rating_numerator  \
# 339  https://twitter.com/dog_rates/status/832273440...              14.0
# 261  https://twitter.com/dog_rates/status/842846295...              13.0
# 828  https://twitter.com/dog_rates/status/768970937...              12.0
#
# ...

# %%
twitter_arc_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1971 non-null   int64
#  1   timestamp           1971 non-null   datetime64[ns, UTC]
#  2   source              1971 non-null   object
#  3   text                1971 non-null   object
#  4   expanded_urls       1971 non-null   object
#  5   rating_numerator    1971 non-null   float64
#  6   rating_denominator  1971 non-null   int64
#  7   name                1349 non-null   object
#  8   doggo               1971 non-null   object
#  9   floofer             1971 non-null   object
#  10  pupper              1971 non-null   object
#  11  puppo               1971 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(2), object(8)
# memory usage: 280.2+ KB

# %%
twitter_arc_clean.loc[new_ratings.index]
# Out:
#                 tweet_id                 timestamp              source  \
# 45    883482846933004288 2017-07-08 00:28:19+00:00  Twitter for iPhone
# 695   786709082849828864 2016-10-13 23:23:56+00:00  Twitter for iPhone
# 763   778027034220126208 2016-09-20 00:24:34+00:00  Twitter for iPhone
# 1712  680494726643068929 2015-12-25 21:06:00+00:00  Twitter for iPhone
#
#                                                    text  \
# 45    This is Bella. She hopes her smile made you sm...
# 695   This is Logan, the Chow who lived. He solemnly...
# 763   This is Sophie. She's a Jubilant Bush Pupper. ...
# 1712  Here we have uncovered an entire battalion of ...
#
#                                           expanded_urls  rating_numerator  \
# 45    https://twitter.com/dog_rates/status/883482846...             13.50
# 695   https://twitter.com/dog_rates/status/786709082...              9.75
# 763   https://twitter.com/dog_rates/status/778027034...             11.27
# ...

# %% [markdown]
# #### 8. Remove values other than 10 for rating_denominator

# %% [markdown]
# ##### define: Remove values other than 10 for rating_denominator

# %% [markdown]
# ##### code :

# %%
twitter_arc_clean = twitter_arc_clean[twitter_arc_clean['rating_denominator'] == 10]

# %% [markdown]
# ##### testing :

# %%
twitter_arc_clean.sample(3)
# Out:
#                 tweet_id                 timestamp  \
# 361   829501995190984704 2017-02-09 01:27:41+00:00
# 418   822462944365645825 2017-01-20 15:17:01+00:00
# 1900  674664755118911488 2015-12-09 18:59:46+00:00
#
#                                                  source  \
# 361   <a href="http://twitter.com/download/iphone" r...
# 418   <a href="http://twitter.com/download/iphone" r...
# 1900  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 361   This is Leo. He was a skater pup. She said see...
# 418   This is Gabe. He was the unequivocal embodimen...
# 1900  This is Rodman. He's getting destroyed by the ...
#
#                                           expanded_urls  rating_numerator  \
# 361   https://twitter.com/dog_rates/status/829501995...              12.0
# 418   https://twitter.com/dog_rates/status/822462944...              14.0
# 1900  https://twitter.com/dog_rates/status/674664755...              10.0
#
# ...

# %%
twitter_arc_clean['rating_denominator'].describe()
# Out:
# count    1954.0
# mean       10.0
# std         0.0
# min        10.0
# 25%        10.0
# 50%        10.0
# 75%        10.0
# max        10.0
# Name: rating_denominator, dtype: float64

# %% [markdown]
# ### Tidiness

# %% [markdown]
# #### 1.Variable dog stage are in 4 columns instead of one in twitter_archive_enh.

# %% [markdown]
# ##### define : extract dog_stage from text and remove une used stages columns

# %% [markdown]
# ##### code :

# %%
# Extract dog stages from 'text' column into new 'dog_stage' column 
# handle none
twitter_arc_clean.doggo.replace('None', '', inplace=True)
twitter_arc_clean.floofer.replace('None', '', inplace=True)
twitter_arc_clean.pupper.replace('None', '', inplace=True)
twitter_arc_clean.puppo.replace('None', '', inplace=True)

# merge into column
twitter_arc_clean['dog_stage'] = twitter_arc_clean.doggo + twitter_arc_clean.floofer + twitter_arc_clean.pupper + twitter_arc_clean.puppo

# handle multiple stages
twitter_arc_clean.loc[twitter_arc_clean.dog_stage == 'doggopupper', 'dog_stage'] = 'doggo, pupper'
twitter_arc_clean.loc[twitter_arc_clean.dog_stage == 'doggopuppo', 'dog_stage'] = 'doggo, puppo'
twitter_arc_clean.loc[twitter_arc_clean.dog_stage == 'doggofloofer', 'dog_stage'] = 'doggo, floofer'

# handle missing values
twitter_arc_clean.loc[twitter_arc_clean.dog_stage == '', 'dog_stage'] = np.nan

# %%
twitter_arc_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1954 entries, 0 to 2355
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1954 non-null   int64
#  1   timestamp           1954 non-null   datetime64[ns, UTC]
#  2   source              1954 non-null   object
#  3   text                1954 non-null   object
#  4   expanded_urls       1954 non-null   object
#  5   rating_numerator    1954 non-null   float64
#  6   rating_denominator  1954 non-null   int64
#  7   name                1346 non-null   object
#  8   doggo               1954 non-null   object
#  9   floofer             1954 non-null   object
#  10  pupper              1954 non-null   object
#  11  puppo               1954 non-null   object
#  12  dog_stage           303 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(2), object(9)
# memory usage: 213.7+ KB

# %%
twitter_arc_clean.sample(3)
# Out:
#                 tweet_id                 timestamp  \
# 1654  683449695444799489 2016-01-03 00:47:59+00:00
# 1965  673345638550134785 2015-12-06 03:38:05+00:00
# 246   845677943972139009 2017-03-25 16:45:08+00:00
#
#                                                  source  \
# 1654  <a href="http://twitter.com/download/iphone" r...
# 1965  <a href="http://twitter.com/download/iphone" r...
# 246   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 1654  I just want to be friends with this dog. Appea...
# 1965  This is Gerald. He's a fluffy lil yellow pup. ...
# 246   C'mon guys. Please only send in dogs. We only ...
#
#                                           expanded_urls  rating_numerator  \
# 1654  https://twitter.com/dog_rates/status/683449695...              10.0
# 1965  https://twitter.com/dog_rates/status/673345638...               7.0
# 246   https://twitter.com/dog_rates/status/845677943...              12.0
#
# ...

# %%
twitter_arc_clean[twitter_arc_clean.dog_stage == 'doggo, pupper']
# Out:
#                 tweet_id                 timestamp  \
# 460   817777686764523521 2017-01-07 16:59:28+00:00
# 531   808106460588765185 2016-12-12 00:29:28+00:00
# 575   801115127852503040 2016-11-22 17:28:25+00:00
# 705   785639753186217984 2016-10-11 00:34:48+00:00
# 889   759793422261743616 2016-07-31 16:50:42+00:00
# 956   751583847268179968 2016-07-09 01:08:47+00:00
# 1063  741067306818797568 2016-06-10 00:39:48+00:00
# 1113  733109485275860992 2016-05-19 01:38:16+00:00
#
#                                                  source  \
# 460   <a href="http://twitter.com/download/iphone" r...
# 531   <a href="http://twitter.com/download/iphone" r...
# 575   <a href="http://twitter.com/download/iphone" r...
# 705   <a href="http://twitter.com/download/iphone" r...
# 889   <a href="http://twitter.com/download/iphone" r...
# 956   <a href="http://twitter.com/download/iphone" r...
# 1063  <a href="http://twitter.com/download/iphone" r...
# ...

# %%
twitter_arc_clean.loc[twitter_arc_clean.dog_stage == 'doggo, puppo']
# Out:
#                tweet_id                 timestamp  \
# 191  855851453814013952 2017-04-22 18:31:02+00:00
#
#                                                 source  \
# 191  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  \
# 191  Here's a puppo participating in the #ScienceMa...
#
#                                          expanded_urls  rating_numerator  \
# 191  https://twitter.com/dog_rates/status/855851453...              13.0
#
#      rating_denominator name     dog_stage
# 191                  10  NaN  doggo, puppo

# %%
twitter_arc_clean[twitter_arc_clean.dog_stage == 'doggo, floofer']
# Out:
#                tweet_id                 timestamp  \
# 200  854010172552949760 2017-04-17 16:34:26+00:00
#
#                                                 source  \
# 200  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  \
# 200  At first I thought this was a shy doggo, but i...
#
#                                          expanded_urls  rating_numerator  \
# 200  https://twitter.com/dog_rates/status/854010172...              11.0
#
#      rating_denominator name       dog_stage
# 200                  10  NaN  doggo, floofer

# %%
# Drop doggo, floofer, pupper, and puppo columns
twitter_arc_clean = twitter_arc_clean.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis=1)

# %% [markdown]
# #### testing :

# %%
twitter_arc_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1954 entries, 0 to 2355
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1954 non-null   int64
#  1   timestamp           1954 non-null   datetime64[ns, UTC]
#  2   source              1954 non-null   object
#  3   text                1954 non-null   object
#  4   expanded_urls       1954 non-null   object
#  5   rating_numerator    1954 non-null   float64
#  6   rating_denominator  1954 non-null   int64
#  7   name                1346 non-null   object
#  8   dog_stage           303 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(2), object(5)
# memory usage: 152.7+ KB

# %% [markdown]
# #### 2.All tables should be part of one dataset

# %% [markdown]
# ##### define : All three tables/dataframes are describing each tweet's info thus should be combined to one.

# %% [markdown]
# ##### code :

# %%
tweet_master_b = pd.merge(twitter_arc_clean, image_predictions_clean, on="tweet_id", how="left")

# %%
tweet_master = pd.merge(tweet_master_b, tweet_json_clean, on="tweet_id", how="left")

# %% [markdown]
# ##### testing :

# %%
tweet_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1954 entries, 0 to 1953
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1954 non-null   int64
#  1   timestamp           1954 non-null   datetime64[ns, UTC]
#  2   source              1954 non-null   category
#  3   text                1954 non-null   object
#  4   expanded_urls       1954 non-null   object
#  5   rating_numerator    1954 non-null   float64
#  6   rating_denominator  1954 non-null   int64
#  7   name                1346 non-null   object
#  8   dog_stage           316 non-null    object
#  9   jpg_url             1954 non-null   object
#  10  img_num             1954 non-null   int64
#  11  p1                  1954 non-null   object
#  12  p1_conf             1954 non-null   float64
#  13  p1_dog              1954 non-null   bool
#  14  p2                  1954 non-null   object
# ...

# %% [markdown]
# ## Storing

# %%
#Store the clean DataFrame in a CSV file
tweet_master.to_csv('twitter_master1.csv', 
                 index=False, encoding = 'utf-8')

# %% [markdown]
# ## Visualizations

# %%
#let's have a look for the ratings distribution by ploting a bar chart for it's frequency.
data = tweet_master.rating_numerator.value_counts()

x = data.index
y = data.values
fig, ax = plt.subplots(figsize=(12, 6))
g = sns.barplot(x, y, palette='Blues_d', ax=ax)
ax.set(xlabel='Ratings', ylabel='Frequency', title='Ratings frequency')
plt.show()

# %%
# As we can see that their are 2 outliers here so let's investigate more and check their data

# %%
outliers_df = tweet_master[tweet_master.rating_numerator > 400][['rating_numerator', 'name', 'jpg_url', 'text']]
outliers_df
# Out:
#       rating_numerator     name  \
# 719             1776.0  Atticus
# 1680             420.0      NaN
#
#                                               jpg_url  \
# 719   https://pbs.twimg.com/media/CmgBZ7kWcAAlzFD.jpg
# 1680  https://pbs.twimg.com/media/CU9P717W4AAOlKx.jpg
#
#                                                    text
# 719   This is Atticus. He's quite simply America af....
# 1680  After so many requests... here you go.\n\nGood...

# %%
from PIL import Image
from io import BytesIO

if not os.path.exists('images'):
    os.makedirs('images')
fig=plt.figure()
c = 1
for index, row in outliers_df.iterrows():
    r = requests.get(row['jpg_url'])
    i = Image.open(BytesIO(r.content))
    i.save('images/' +  str(index) + '_' + str(row['rating_numerator']) + "_" + str(row['name']) + '.jpg')
    fig.add_subplot(1, 2, c)
    c += 1
    plt.imshow(i)
    plt.axis("off")
plt.show()

# %%
tweet_master[tweet_master['rating_numerator']== 420]
# Out:
#                 tweet_id                 timestamp              source  \
# 1680  670842764863651840 2015-11-29 05:52:33+00:00  Twitter for iPhone
#
#                                                    text  \
# 1680  After so many requests... here you go.\n\nGood...
#
#                                           expanded_urls  rating_numerator  \
# 1680  https://twitter.com/dog_rates/status/670842764...             420.0
#
#       rating_denominator name dog_stage  \
# 1680                  10  NaN       NaN
#
#                                               jpg_url  ...   p1_conf p1_dog  \
# 1680  https://pbs.twimg.com/media/CU9P717W4AAOlKx.jpg  ...  0.096063  False
#
#              p2   p2_conf p2_dog         p3   p3_conf p3_dog  retweet_count  \
# 1680  accordion  0.094075  False  drumstick  0.061113  False           4324
#
#       favorite_count
# 1680            7989
#
# [1 rows x 22 columns]

# %%
tweet_master.shape
# Out:
# (1954, 22)

# %%
#420 rating score is the rap star Snoop Dogg and should be removed from our data
tweet_master.drop(index=1680, inplace=True)

# %%
tweet_master.shape
# Out:
# (1953, 22)

# %% [markdown]
# ### 1.there are two tweets, first one has 'rating_numerator' = 1776.0 and  another one  has 'rating_numerator' = 420
# ### The first is actually a picture of a dog, while the second is a picture of a person

# %%
# Next we can look for the relation betwee 'retweet_count' and 'favorite_count'

# %%
# Scatter plot to show the relation between favorits and retweets
ax = sns.scatterplot(x='retweet_count', y='favorite_count', data=tweet_master,
                     hue='rating_numerator', hue_norm=(5, 20), s=15) 
ax.set(xlabel='Retweet count', ylabel='Favorite count', title='Favorits VS Retweets')
plt.show()

# %%
ax = sns.lmplot(x="retweet_count", y="favorite_count", data=tweet_master, size = 5, aspect=1.3, scatter_kws={'alpha':1/5})
ax.set(xlabel='Retweet count', ylabel='Favorite count', title='Favorits VS Retweets')

# %% [markdown]
# ### 2.As we expected the favorite and retweets are highly postive correlated

# %%
#Comparing tweets different sources

# %%
data = tweet_master.groupby('source').count()['tweet_id']
ax = sns.barplot(y=data.index, x=data.values, palette='Blues_d')
ax.set(xlabel='Count', ylabel='Tweet source', title='Tweet Source Counts')
plt.show()

# %% [markdown]
# #### 3. People who have iphone are the most interested in dogs

# %%
#Popularity of Dog Breeds

# %%
# Get attributes before determinig dog breed
attributes = ['retweet_count', 'favorite_count', 'rating_denominator', 'rating_numerator']
df_dog_breeds = tweet_master[attributes].copy()

# Create rating column
def percent_rating(row):
    if row['rating_denominator'] == 0:
        return 0
    return row['rating_numerator']/row['rating_denominator']


df_dog_breeds['rating'] = df_dog_breeds.apply(percent_rating, axis=1)

# %%
# Get needed attributes for possible dog
attributes = ['p1', 'p1_dog', 'p1_conf', 'p2', 'p2_dog', 'p2_conf', 'p3', 'p3_dog', 'p3_conf']
df_possible_breeds = tweet_master[attributes].copy()

# Create default for breeds and confidence
df_possible_breeds['breed'] = ''
df_possible_breeds['breed_conf'] = 1

# For each entry, check which is the most likely breed
def best_breed_match(row):
    
    # Defaults to compare against
    breed = 'not_dog'
    confidence = 0
    
    # Only keep if it is a possible dog
    dog_preds = [(row[['p1', 'p1_dog', 'p1_conf']]), (row[['p2', 'p2_dog', 'p2_conf']]), (row[['p3', 'p3_dog', 'p3_conf']])]
    # Use this for easy reference
    index_breed, index_isDog, index_conf = 0,1,2
    
    for pred in dog_preds:
        # If it's a dog breed, check if it's max confidence seen
        if pred[index_isDog]:
            # save breed and confidence if higher confidence
            if pred[index_conf] >= confidence:
                breed = pred[index_breed]
                confidence = pred[index_conf]
    
    # Update breed list
    row['breed'] = breed
    row['breed_conf'] = confidence
    return row
        
    breeds = [row['p1'], row['p2'], row['p3']]
    
    
df_possible_breeds = df_possible_breeds.apply(best_breed_match, axis=1)

# Save info into dog breed dataframe
df_dog_breeds['breed'] = df_possible_breeds['breed']

df_dog_breeds['breed_conf'] = df_possible_breeds['breed_conf']

# %%
# show 30 most common dog breeds
df_dog_breeds.breed.value_counts()[:30] # 'not_dog' is most common so keep this out of plot
# Out:
# not_dog                           303
# golden_retriever                  153
# Labrador_retriever                103
# Pembroke                           94
# Chihuahua                          89
# pug                                62
# toy_poodle                         50
# chow                               47
# Samoyed                            42
# Pomeranian                         41
# malamute                           33
# Chesapeake_Bay_retriever           31
# French_bulldog                     31
# cocker_spaniel                     30
# miniature_pinscher                 24
# Eskimo_dog                         22
# Cardigan                           21
# German_shepherd                    21
# Shih-Tzu                           20
# beagle                             20
# Staffordshire_bullterrier          20
# Siberian_husky                     19
# Rottweiler                         18
# Shetland_sheepdog                  18
# Maltese_dog                        18
# ...

# %%
df_dog_breeds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1953 entries, 0 to 1953
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   retweet_count       1953 non-null   int64
#  1   favorite_count      1953 non-null   int64
#  2   rating_denominator  1953 non-null   int64
#  3   rating_numerator    1953 non-null   float64
#  4   rating              1953 non-null   float64
#  5   breed               1953 non-null   object
#  6   breed_conf          1953 non-null   float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 122.1+ KB

# %%
# Plot the 12 most common dog breeds in bar chart
only_dogs = df_dog_breeds['breed'] != 'not_dog'
df_dog_breeds[only_dogs].breed.value_counts()[12::-1].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4.Golden retriever is the most common dog in this dataset
